# %%
from PyPDFForm import PdfWrapper, FormWrapper
from pathlib import Path
import json

# ✅ Set the path to your local fillable PDF
pdf_path = Path("data/sample.pdf")  # <- Change this to your test file

# ✅ Load the PDF
pdf = PdfWrapper(str(pdf_path))

# ✅ View the full schema
print("=== Full Schema ===")
print(json.dumps(pdf.schema, indent=2))

# # ✅ Get the field names (top-level keys)
# field_names = list(pdf.schema.get("properties", {}).keys())
# print("\n=== Field Names ===")
# print(field_names)

# # ✅ Inspect individual field types
# print("\n=== Field Types ===")
# for field in field_names:
#     field_info = pdf.schema["properties"].get(field, {})
#     print(f"{field}: {field_info.get('type')}")

# # ✅ Optional: Fill with test data (simulated)
# test_data = {
#     field: (True if pdf.schema["properties"][field]["type"] == "boolean" else f"test_{field}")
#     for field in field_names
# }

# # ✅ Fill form and save to file
# filled = FormWrapper(str(pdf_path)).fill(test_data, flatten=False)
# output_path = pdf_path.with_stem(f"debug_filled_{pdf_path.stem}")
# with open(output_path, "wb") as f:
#     f.write(filled.read())

# print(f"\nFilled PDF saved to: {output_path}")
# Out:
# === Full Schema ===
# {
#   "type": "object",
#   "properties": {
#     "1 First name": {
#       "type": "string",
#       "description": "1. First name"
#     },
#     "Middle name": {
#       "type": "string",
#       "description": "Middle name"
#     },
#     "Last name": {
#       "type": "string",
#       "description": "Last name"
#     },
#     "Suffix": {
#       "type": "string"
#     },
#     "undefined": {
#       "type": "boolean",
#       "description": "undefined"
#     },
#     "2 Home address If Homeless please write Homeless here with appropriate city state and zip code and mark this box": {
#       "type": "string",
#       "description": "2. Home address -If Homeless, please write \u201cHomeless\u201d here with appropriate city, state and zip code and mark this box"
#     },
#     "3 Apartment or suite number": {
#       "type": "string",
#       "description": "3. Apartment or suite number"
#     },
#     "4 City": {
#       "type": "string",
# ...
